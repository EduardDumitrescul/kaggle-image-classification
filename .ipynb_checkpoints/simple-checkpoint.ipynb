# %%
import numpy as np
from PIL import Image
import pandas as pd
import os

# %%
# %%time

# Loads filenames, images and labels 
# Reshapes images to (80, 80, 3)

def load_data(name):
    df = pd.read_csv(name + '.csv')
    df_sorted = df.sort_values(by='image_id')

    labelDict = dict()
    labels = df_sorted.values
    for entry in labels:
        try:
            labelDict[entry[0]] = entry[1]
        except:
            labelDict[entry[0]] = 0

    images = []
    labels = []
    filenames = []
    for filename in os.listdir(name):
        if filename.endswith('.png'):
            file_path = os.path.join(name, filename)
            image = Image.open(file_path)
            image_array = np.array(image)
            if filename[:-4] in labelDict.keys():
                filenames.append(filename[:-4])
                images.append(image_array)
                labels.append(labelDict[filename[:-4]])

    for i in range(len(images)):
        if images[i].shape != (80, 80, 3):
            images[i] = np.stack((images[i], images[i], images[i]), axis=-1)

    images = np.array(images)
    labels = np.array(labels)

    return filenames, images, labels

training_filenames, training_images, training_labels = load_data("train")
print(f"Training: {np.shape(training_images)} - {np.shape(training_labels)}")

validation_filenames, validation_images, validation_labels = load_data("validation")
print(f"Validation: {np.shape(validation_images)} - {np.shape(validation_labels)}")

test_filenames, test_images, test_labels = load_data("test")
print(f"Test: {np.shape(test_images)} - {np.shape(test_labels)}")
# Out:
# Training: (10500, 80, 80, 3) - (10500,)
# Validation: (3000, 80, 80, 3) - (3000,)
# Test: (4500, 80, 80, 3) - (4500,)
# CPU times: user 4.69 s, sys: 650 ms, total: 5.34 s
# Wall time: 5.34 s

# %%
# Standardize images
import matplotlib.pyplot as plt

standard_training_images = (training_images - np.mean(training_images, axis=(0, 1, 2))) / np.std(training_images, axis=(0, 1, 2))
standard_validation_images = (validation_images - np.mean(validation_images, axis=(0, 1, 2))) / np.std(validation_images, axis=(0, 1, 2))
standard_test_images = (test_images - np.mean(test_images, axis=(0, 1, 2))) / np.std(test_images, axis=(0, 1, 2))

for i in range(5):
    plt.imshow(standard_training_images[i])
    plt.title(f'Label: {training_labels[i]}')
    plt.show()
    plt.savefig(f"temp/{i}.png)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.866021677121433..1.3809394968809152].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4000328566778901..1.9680136320767012].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.911117369422421..2.082564682846611].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8509897796877703..1.6063466300546445].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.6248431374475005..2.025289157461656].

# %%
# %%time
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
flat_training_images = scaler.fit_transform(standard_training_images.reshape((10500, 80*80*3)))
flat_validation_images = scaler.fit_transform(standard_validation_images.reshape((3000, 80*80*3)))


from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB().fit(flat_training_images, training_labels)
score = str(mnb.score(flat_validation_images, validation_labels))
print("score on test: " + str(score))
# Out:
# score on test: 0.418
# CPU times: user 4.58 s, sys: 3.34 s, total: 7.91 s
# Wall time: 4.28 s

# %%
# %%time
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import skimage.measure

scaler = MinMaxScaler()
flat_training_images = scaler.fit_transform(training_images.reshape((10500, 80*80*3)))
flat_validation_images = scaler.fit_transform(validation_images.reshape((3000, 80*80*3)))

reduced_training_images = (skimage.measure.block_reduce(training_images, (1,4,4,1), np.max)).reshape((10500, 10*40*3))
print(np.shape(reduced_training_images))S
reduced_validation_images = (skimage.measure.block_reduce(validation_images, (1,4,4, 1), np.max)).reshape((3000, 40*40*3))

clf = svm.SVC(decision_function_shape='ovo', verbose=True, max_iter=100, kernel="rbf")
clf.fit(reduced_training_images, training_labels)
score = clf.score(reduced_validation_images, validation_labels)

print("score on test: " + str(score))
# Out:
# (10500, 1200)
# [LibSVM].....*.*
# optimization finished, #iter = 6343
# obj = -4135.557480, rho = 0.007929
# nSV = 5900, nBSV = 4396
# .....*.*
# optimization finished, #iter = 6786
# obj = -4015.457183, rho = -0.483930
# nSV = 5756, nBSV = 4206
# .....*..*
# optimization finished, #iter = 7208
# obj = -4296.380467, rho = -0.289900
# nSV = 5999, nBSV = 4391
# Total nSV = 9718
# score on test: 0.5396666666666666
# CPU times: user 1min 7s, sys: 667 ms, total: 1min 8s
# Wall time: 1min 8s

# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.23.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23 in /home/eduard/.config/jupyterlab-desktop/envs/env_3/lib/python3.12/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /home/eduard/.config/jupyterlab-desktop/envs/env_3/lib/python3.12/site-packages (from scikit-image) (1.13.1)
# Collecting networkx>=2.8 (from scikit-image)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow>=9.1 in /home/eduard/.config/jupyterlab-desktop/envs/env_3/lib/python3.12/site-packages (from scikit-image) (10.3.0)
# Collecting imageio>=2.33 (from scikit-image)
#   Downloading imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.5.22-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in /home/eduard/.config/jupyterlab-desktop/envs/env_3/lib/python3.12/site-packages (from scikit-image) (24.0)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.23.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 538.4 kB/s eta 0:00:0000:0100:01
# Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 531.0 kB/s eta 0:00:0000:0100:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 534.3 kB/s eta 0:00:0000:0100:01
# Downloading tifffile-2024.5.22-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.5/225.5 kB 176.1 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: tifffile, networkx, lazy-loader, imageio, scikit-image
# Successfully installed imageio-2.34.1 lazy-loader-0.4 networkx-3.3 scikit-image-0.23.2 tifffile-2024.5.22
# Note: you may need to restart the kernel to use updated packages.
